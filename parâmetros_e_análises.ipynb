# %% [markdown]
# <a href="https://colab.research.google.com/github/lkramerpezzin/lkramerpezzin/blob/main/par%C3%A2metros_e_an%C3%A1lises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Leonardo Kramer Pezzin
# 14/02/23

# %% [markdown]
# #Parâmetros

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv('/content/drive/MyDrive/analise MEIS/parâmetros.csv', names=['concentração', 'A', 'B', 'C', 'D'], sep=':')

display(df)
paramB= df['B']
Bs= np.array(paramB)

paramC= df['C']
Cs= np.array(paramC)
# Out:
#             concentração            A           B         C         D
# 0,25g/L        H_Au_110   1224.454928  146.836871  0.376887  1.656745
# 0,25g/L        H_Au_120   1316.740895  146.586876  0.320193  5.643988
# 0,25g/L        H_Au_130   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L        H_Au_110   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L        H_Au_120   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L        H_Au_130   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L       H_025_110   1275.622623  146.496518  0.367572  0.488068
# 0,25g/L       H_025_120   1375.619591  146.279223  0.330229  3.608103
# 0,25g/L       H_025_130   1285.043651  145.970789  0.347514  3.147034
# 0,25g/L      H2_025_110   1197.835851  147.177918  0.430562  0.557749
# 0,25g/L      H2_025_120   1282.615604  146.928134  0.417882  2.340846
# 0,25g/L      H2_025_130   1197.907881  146.666677  0.413030  2.473185
# ...

# %%
# Guardando valores de B de H para Au
BHAu_lista= list()
BH2Au_lista= list()

# Guardando valores de B de H para os filmes

BH_lista= list()
BH2_lista= list()

# Pegando valores de H para Au
BHAu_lista.append(df['B'].iloc[:6])
BHAu_lista.append(df['B'].iloc[13:18])
BHAu_lista.append(df['B'].iloc[24:27])
BHAu_lista.append(df['B'].iloc[36:39])
BHAu_lista.append(df['B'].iloc[48:51])


# Pegando valores de H2 para Au
BH2Au_lista.append(df['B'].iloc[24:27])
BH2Au_lista.append(df['B'].iloc[27:30])
BH2Au_lista.append(df['B'].iloc[39:42])
BH2Au_lista.append(df['B'].iloc[51:54])

# Pegando valores de H para filme
BH_lista.append(df['B'].iloc[6:9])
BH_lista.append(df['B'].iloc[18:21])
BH_lista.append(df['B'].iloc[30:33])
BH_lista.append(df['B'].iloc[42:45])
BH_lista.append(df['B'].iloc[54:57])

# Pegando valores de H2 para filme
BH2_lista.append(df['B'].iloc[9:12])
BH2_lista.append(df['B'].iloc[21:24])
BH2_lista.append(df['B'].iloc[33:36])
BH2_lista.append(df['B'].iloc[45:48])
BH2_lista.append(df['B'].iloc[57:60])

import numpy as np
BHAu_ = np.concatenate(BHAu_lista)
BH2Au_ = np.concatenate(BH2Au_lista)
BH_ = np.concatenate(BH_lista)
BH2_ = np.concatenate(BH2_lista)

# %%
# Guardando valores de B
Bfilm110 = df.iloc[6:14:2, df.columns.get_loc("B")].to_numpy()
Bfilm120 = df.iloc[18:23:2, df.columns.get_loc("B")].to_numpy()
Bfilm130 = df.iloc[29:35:2, df.columns.get_loc("B")].to_numpy()

print(np.size(Bfilm110), Bfilm110)
print(np.size(Bfilm120), Bfilm120)
print(np.size(Bfilm130), Bfilm130)
# Out:
# 4 [146.49651807 145.97078871 146.92813405 146.83687088]
# 3 [146.54922678 146.0147092  146.98620083]
# 3 [146.54266001 146.08146146 146.96854768]

# %%
# Divididos por concentração
print('0,25g/L')
display(df.iloc[0:14])  

print('0,5g/L')
display(df.iloc[15:23])

print('1g/L')
display(df.iloc[24:35])

print('2g/L')
display(df.iloc[36:47])

print('3g/L')
display(df.iloc[48:60])
# Out:
# 0,25g/L
#           concentração            A           B         C         D
# 0,25g/L      H_Au_110   1224.454928  146.836871  0.376887  1.656745
# 0,25g/L      H_Au_120   1316.740895  146.586876  0.320193  5.643988
# 0,25g/L      H_Au_130   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L      H_Au_110   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L      H_Au_120   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L      H_Au_130   1236.170885  146.287186  0.333384  2.499097
# 0,25g/L     H_025_110   1275.622623  146.496518  0.367572  0.488068
# 0,25g/L     H_025_120   1375.619591  146.279223  0.330229  3.608103
# 0,25g/L     H_025_130   1285.043651  145.970789  0.347514  3.147034
# 0,25g/L    H2_025_110   1197.835851  147.177918  0.430562  0.557749
# 0,25g/L    H2_025_120   1282.615604  146.928134  0.417882  2.340846
# 0,25g/L    H2_025_130   1197.907881  146.666677  0.413030  2.473185
# 0,25g/L      H_Au_110   1224.454928  146.836871  0.376887  1.656745
# ...

# %%
j= 0
i= 1
k= 2

# Guardando valores de B
Bfilm110= list()          #Guarda todos os valores de B em 110° só filmes
Bfilm120= list()          #Guarda todos os valores de B em 120° só filmes
Bfilm130= list()          #Guarda todos os valores de B em 130° só filmes

while (j<np.size(Bs)):
  if (j> 5 and j<12): #captura H e H2 dos filmes de 0,25g/L
    Bfilm110.append(Bs[j])
  if (j> 17 and j<23): #captura H e H2 dos filmes de 0,5g/L
    Bfilm110.append(Bs[j])
  if (j> 28 and j<35): #captura H e H2 dos filmes de 1g/L
    Bfilm110.append(Bs[j])
  if (j> 40 and j<47): #captura H e H2 dos filmes de 2g/L
    Bfilm110.append(Bs[j])
  if (j> 52 and j<60): #captura H e H2 dos filmes de 3g/L
    Bfilm110.append(Bs[j])
  j+= 3

while (i<np.size(Bs)):
  if (i> 5 and i<12): #captura H e H2 dos filmes de 0,25g/L
    Bfilm120.append(Bs[i])
  if (i> 17 and i<23): #captura H e H2 dos filmes de 0,5g/L
    Bfilm120.append(Bs[i])
  if (i> 28 and i<35): #captura H e H2 dos filmes de 1g/L
    Bfilm120.append(Bs[i])
  if (i> 40 and i<47): #captura H e H2 dos filmes de 2g/L
    Bfilm120.append(Bs[i])
  if (i> 52 and i<60): #captura H e H2 dos filmes de 3g/L
    Bfilm120.append(Bs[i])
  i+= 3

while (k<np.size(Bs)):
  if (k> 5 and k<12): #captura H e H2 dos filmes de 0,25g/L
    Bfilm130.append(Bs[k])
  if (k> 18 and k<23): #captura H e H2 dos filmes de 0,5g/L
    Bfilm130.append(Bs[k])
  if (k> 28 and k<35): #captura H e H2 dos filmes de 1g/L
    Bfilm130.append(Bs[k])
  if (k> 40 and k<47): #captura H e H2 dos filmes de 2g/L
    Bfilm130.append(Bs[k])
  if (k> 52 and k<60): #captura H e H2 dos filmes de 3g/L
    Bfilm130.append(Bs[k])
  k+= 3

print(np.size(Bfilm110),Bfilm110)
print(np.size(Bfilm120),Bfilm120)
print(np.size(Bfilm130),Bfilm130)
# Out:
# 10 [146.49651807048045, 147.17791771755626, 146.5492267770827, 147.2735283628445, 146.30617355367357, 146.96854768480597, 146.1336512059083, 146.9692868560522, 146.19530635084317, 147.00250182545267]
# 10 [146.27922266178163, 146.92813405087753, 146.32614802905698, 146.98620082710582, 146.08146145598184, 146.70839630408312, 145.91045525353528, 146.73666601355868, 145.98414498911222, 146.73532435984058]
# 10 [145.97078870506024, 146.66667671417093, 146.01470920350744, 146.54266000898082, 145.7418547513611, 146.5709235715543, 145.60961682559733, 146.57618130840942, 145.65725947385386, 146.45300196393114]

# %%
# Só os H
B_H_110= list()
B_H_120= list()
B_H_130= list()

i= 0
while (i< np.size(Bfilm110)):
  B_H_110.append(Bfilm110[i])
  B_H_120.append(Bfilm120[i])
  B_H_130.append(Bfilm130[i])            
  i+= 2

# Só os H2
B_H2_110= list()
B_H2_120= list()
B_H2_130= list()

j= 1
while (j< np.size(Bfilm120)):
  B_H2_110.append(Bfilm110[j])
  B_H2_120.append(Bfilm120[j])
  B_H2_130.append(Bfilm130[j])            
  j+= 2

print('H nos filmes 110°', B_H_110)
print('H nos filmes 120°', B_H_120)
print('H nos filmes 130°', B_H_130)
print('H2 nos filmes 110°', B_H2_110)
print('H2 nos filmes 120°', B_H2_120)
print('H2 nos filmes 120°', B_H2_130)
# Out:
# H nos filmes 110° [146.49651807048045, 146.5492267770827, 146.30617355367357, 146.1336512059083, 146.19530635084317]
# H nos filmes 120° [146.27922266178163, 146.32614802905698, 146.08146145598184, 145.91045525353528, 145.98414498911222]
# H nos filmes 130° [145.97078870506024, 146.01470920350744, 145.7418547513611, 145.60961682559733, 145.65725947385386]
# H2 nos filmes 110° [147.17791771755626, 147.2735283628445, 146.96854768480597, 146.9692868560522, 147.00250182545267]
# H2 nos filmes 120° [146.92813405087753, 146.98620082710582, 146.70839630408312, 146.73666601355868, 146.73532435984058]
# H2 nos filmes 120° [146.66667671417093, 146.54266000898082, 146.5709235715543, 146.57618130840942, 146.45300196393114]

# %%
print('B:', Bs)
print('C:', Cs)
# Out:
# B: [146.83687088 146.58687636 146.28718639 146.28718639 146.28718639
#  146.28718639 146.49651807 146.27922266 145.97078871 147.17791772
#  146.92813405 146.66667671 146.83687088 146.58687636 146.28718639
#  147.34054884 147.05291153 146.28718639 146.54922678 146.32614803
#  146.0147092  147.27352836 146.98620083 146.72764959 146.2691055
#  146.00837415 145.65323786 147.14974616 146.84470568 146.54266001
#  146.30617355 146.08146146 145.74185475 146.96854768 146.7083963
#  146.43249889 146.09846846 145.88650687 145.57347919 147.1202665
#  146.85267197 146.57092357 146.13365121 145.91045525 145.60961683
#  146.96928686 146.73666601 146.47035441 146.3837832  146.11751431
#  145.77639142 147.12906656 146.85654388 146.57618131 146.19530635
#  145.98414499 145.65725947 147.00250183 146.73532436 146.45300196]
# C: [0.37688745 0.32019297 0.33338374 0.33338374 0.33338374 0.33338374
#  0.3675718  0.33022909 0.34751356 0.43056164 0.41788188 0.41303009
# ...

# %% [markdown]
# ###B

# %%
x= [0.25, 0.5, 1, 2, 3]
plt.plot(x, B_H_110, 'o', color='navy', label='H 110°')
plt.plot(x, B_H_120, 'o', color='darkgreen', label='H 120°')
plt.plot(x, B_H_130, 'o', color= 'red', label='H 130°')
plt.title('Valores de B para H')
plt.xlabel('Concentração [g/L]')
plt.ylabel('B')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)


plt.show()

# %%
x= [0.25, 0.5, 1, 2, 3]
plt.plot(x, B_H2_110, 'o', color='cyan', label='H2 110°')
plt.plot(x, B_H2_120, 'o', color='limegreen', label='H2 120°')
plt.plot(x, B_H2_130, 'o', color= 'firebrick', label='H2 130°')
plt.title('Valores de B para H2')
plt.xlabel('Concentração [g/L]')
plt.ylabel('B')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %%
x= [0.25, 0.5, 1, 2, 3]

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 7))

plt.plot(x, B_H_110, 'o', color='navy', label='H 110°')
plt.plot(x, B_H_120, 'o', color='darkgreen', label='H 120°')
plt.plot(x, B_H_130, 'o', color= 'red', label='H 130°')
plt.plot(x, B_H2_110, 'o', color='cyan', label='H2 110°')
plt.plot(x, B_H2_120, 'o', color='limegreen', label='H2 120°')
plt.plot(x, B_H2_130, 'o', color= 'firebrick', label='H2 130°')
plt.title('Valores de B para H e H2')
plt.xlabel('Concentração [g/L]')
plt.ylabel('B')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)


plt.show()

# %% [markdown]
# ###C

# %%
j= 0
i= 1
k= 2

# Guardando valores de C
Cfilm110= list()          #Guarda todos os valores de C em 110° só filmes
Cfilm120= list()          #Guarda todos os valores de C em 120° só filmes
Cfilm130= list()          #Guarda todos os valores de C em 130° só filmes

while (j<np.size(Cs)):
  if (j> 5 and j<12): #captura H e H2 dos filmes de 0,25g/L
    Cfilm110.append(Cs[j])
  if (j> 17 and j<23): #captura H e H2 dos filmes de 0,5g/L
    Cfilm110.append(Cs[j])
  if (j> 28 and j<35): #captura H e H2 dos filmes de 1g/L
    Cfilm110.append(Cs[j])
  if (j> 40 and j<47): #captura H e H2 dos filmes de 2g/L
    Cfilm110.append(Cs[j])
  if (j> 52 and j<60): #captura H e H2 dos filmes de 3g/L
    Cfilm110.append(Cs[j])
  j+= 3

while (i<np.size(Cs)):
  if (i> 5 and i<12): #captura H e H2 dos filmes de 0,25g/L
    Cfilm120.append(Cs[i])
  if (i> 17 and i<23): #captura H e H2 dos filmes de 0,5g/L
    Cfilm120.append(Cs[i])
  if (i> 28 and i<35): #captura H e H2 dos filmes de 1g/L
    Cfilm120.append(Cs[i])
  if (i> 40 and i<47): #captura H e H2 dos filmes de 2g/L
    Cfilm120.append(Cs[i])
  if (i> 52 and i<60): #captura H e H2 dos filmes de 3g/L
    Cfilm120.append(Cs[i])
  i+= 3

while (k<np.size(Cs)):
  if (k> 5 and k<12): #captura H e H2 dos filmes de 0,25g/L
    Cfilm130.append(Cs[k])
  if (k> 18 and k<23): #captura H e H2 dos filmes de 0,5g/L
    Cfilm130.append(Cs[k])
  if (k> 28 and k<35): #captura H e H2 dos filmes de 1g/L
    Cfilm130.append(Cs[k])
  if (k> 40 and k<47): #captura H e H2 dos filmes de 2g/L
    Cfilm130.append(Cs[k])
  if (k> 52 and k<60): #captura H e H2 dos filmes de 3g/L
    Cfilm130.append(Cs[k])
  k+= 3

print(np.size(Cfilm110),Cfilm110)
print(np.size(Cfilm120),Cfilm120)
print(np.size(Cfilm130),Cfilm130)
# Out:
# 10 [0.3675718009373519, 0.4305616409853653, 0.3656440813660596, 0.3659074992311599, 0.3414099276441313, 0.4443553317741321, 0.3453709262918529, 0.4505803597604915, 0.3461415352016114, 0.4275018441200601]
# 10 [0.3302290863660748, 0.4178818777567198, 0.3173192136515214, 0.3661469712629437, 0.3030712828638023, 0.4344944043566978, 0.3543220077820132, 0.4245111828540635, 0.342382975518455, 0.4003058716858863]
# 10 [0.3475135648729919, 0.413030094525857, 0.3396016895053895, 0.3770538884853786, 0.3166243165389165, 0.3532298421532633, 0.3054515259070824, 0.3692950082643473, 0.3415567244231606, 0.4194318973057395]

# %%
# C
# Só os H
C_H_110= list()
C_H_120= list()
C_H_130= list()

i= 0
while (i< np.size(Cfilm110)):
  C_H_110.append(Cfilm110[i])
  C_H_120.append(Cfilm120[i])
  C_H_130.append(Cfilm130[i])            
  i+= 2

# Só os H2
C_H2_110= list()
C_H2_120= list()
C_H2_130= list()

j= 1
while (j< np.size(Cfilm120)):
  C_H2_110.append(Cfilm110[j])
  C_H2_120.append(Cfilm120[j])
  C_H2_130.append(Cfilm130[j])            
  j+= 2

print('H nos filmes 110°', C_H_110)
print('H nos filmes 120°', C_H_120)
print('H nos filmes 130°', C_H_130)
print('H2 nos filmes 110°', C_H2_110)
print('H2 nos filmes 120°', C_H2_120)
print('H2 nos filmes 120°', C_H2_130)
# Out:
# H nos filmes 110° [0.3675718009373519, 0.3656440813660596, 0.3414099276441313, 0.3453709262918529, 0.3461415352016114]
# H nos filmes 120° [0.3302290863660748, 0.3173192136515214, 0.3030712828638023, 0.3543220077820132, 0.342382975518455]
# H nos filmes 130° [0.3475135648729919, 0.3396016895053895, 0.3166243165389165, 0.3054515259070824, 0.3415567244231606]
# H2 nos filmes 110° [0.4305616409853653, 0.3659074992311599, 0.4443553317741321, 0.4505803597604915, 0.4275018441200601]
# H2 nos filmes 120° [0.4178818777567198, 0.3661469712629437, 0.4344944043566978, 0.4245111828540635, 0.4003058716858863]
# H2 nos filmes 120° [0.413030094525857, 0.3770538884853786, 0.3532298421532633, 0.3692950082643473, 0.4194318973057395]

# %%
# Guardando valores de B de H para Au
CHAu_lista= list()
CH2Au_lista= list()

# Guardando valores de B de H para os filmes
CH_lista= list()
CH2_lista= list()

# Pegando valores de H para Au
CHAu_lista.append(df['C'].iloc[:6])
CHAu_lista.append(df['C'].iloc[13:18])
CHAu_lista.append(df['C'].iloc[24:27])
CHAu_lista.append(df['C'].iloc[36:39])
CHAu_lista.append(df['C'].iloc[48:51])


# Pegando valores de H2 para Au
CH2Au_lista.append(df['C'].iloc[24:27])
CH2Au_lista.append(df['C'].iloc[27:30])
CH2Au_lista.append(df['C'].iloc[39:42])
CH2Au_lista.append(df['C'].iloc[51:54])

# Pegando valores de H para filme
CH_lista.append(df['C'].iloc[6:9])
CH_lista.append(df['C'].iloc[18:21])
CH_lista.append(df['C'].iloc[30:33])
CH_lista.append(df['C'].iloc[42:45])
CH_lista.append(df['C'].iloc[54:57])

# Pegando valores de H2 para filme
CH2_lista.append(df['C'].iloc[9:12])
CH2_lista.append(df['C'].iloc[21:24])
CH2_lista.append(df['C'].iloc[33:36])
CH2_lista.append(df['C'].iloc[45:48])
CH2_lista.append(df['C'].iloc[57:60])

import numpy as np
CHAu_ = np.concatenate(CHAu_lista)
CH2Au_ = np.concatenate(CH2Au_lista)
CH_ = np.concatenate(CH_lista)
CH2_ = np.concatenate(CH2_lista)

# %%
x= [0.25, 0.5, 1, 2, 3]
plt.plot(x, C_H_110, 'o', color='navy', label='H 110°')
plt.plot(x, C_H_120, 'o', color='darkgreen', label='H 120°')
plt.plot(x, C_H_130, 'o', color= 'red', label='H 130°')
plt.title('Valores de C para H')
plt.xlabel('Concentração [g/L]')
plt.ylabel('C')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %%
x= [0.25, 0.5, 1, 2, 3]
plt.plot(x, C_H2_110, 'o', color='cyan', label='H2 110°')
plt.plot(x, C_H2_120, 'o', color='limegreen', label='H2 120°')
plt.plot(x, C_H2_130, 'o', color= 'firebrick', label='H2 130°')
plt.title('Valores de C para H2')
plt.xlabel('Concentração [g/L]')
plt.ylabel('C')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %% [markdown]
# ##Comparação

# %%
# Parâmetro B
BH_110= list()
BH2_110= list()
k= 0
m= 0
#m= 0

while k<len(BH_):
  BH_110.append(BH_[k])
  k+= 3

while m<len(BH2_):
  BH2_110.append(BH2_[m])
  m+= 3

import matplotlib.pyplot as plt
plt.plot(BH_, 'o', label= 'H')
plt.plot(BH2_, 'o', label='H2')
plt.title('Parâmetro B')
plt.ylabel('B')
plt.xlabel('concentração [g/L]')
plt.legend()
plt.show()

plt.plot(BH_110, 'o', color= 'darkred', label= 'H')
plt.plot(BH2_110, 'o',color= 'yellowgreen', label= 'H2')
plt.title('Parâmetro B em 110°')
plt.ylabel('B')
plt.xlabel('concentração [g/L]')
plt.legend()
plt.show()

# %% [markdown]
# ####Todos os C

# %%
x= [0.25, 0.5, 1, 2, 3]

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 7))

plt.plot(x, C_H_110, 'o', color='navy', label='H 110°')
plt.plot(x, C_H_120, 'o', color='darkgreen', label='H 120°')
plt.plot(x, C_H_130, 'o', color= 'red', label='H 130°')
plt.plot(x, C_H2_110, 'o', color='cyan', label='H2 110°')
plt.plot(x, C_H2_120, 'o', color='limegreen', label='H2 120°')
plt.plot(x, C_H2_130, 'o', color= 'firebrick', label='H2 130°')
plt.title('Valores de C para H e H2')
plt.xlabel('Concentração [g/L]')
plt.ylabel('C')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)


plt.show()

# %%
# Parâmetros c
CH_110= list()
CH2_110= list()
k= 0
m= 0

while k<len(CH_):
  CH_110.append(CH_[k])
  k+= 3

while m<len(CH2_):
  CH2_110.append(CH2_[m])
  m+= 3

import matplotlib.pyplot as plt
plt.plot(CH_, 'o', label= 'H')
plt.plot(CH2_, 'o', label='H2')
plt.title('Parâmetro C')
plt.ylabel('C')
plt.xlabel('concentração [g/L]')
plt.legend()
plt.show()

plt.plot(CH_110, 'o', color= 'darkred', label= 'H')
plt.plot(CH2_110, 'o',color= 'yellowgreen', label= 'H2')
plt.title('Parâmetro C em 110°')
plt.ylabel('C')
plt.xlabel('concentração [g/L]')
plt.legend()
plt.show()
